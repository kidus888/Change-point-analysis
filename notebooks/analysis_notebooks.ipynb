# %%
import sys
sys.path.append('../scripts')

# %%
from analysis import load_data, preprocess_data,  plot_price, rolling_statistics, add_moving_averages, train_arima_model, evaluate_model

# %%
# Load data

data = load_data('../data/Copy of BrentOilPrices.csv')

# %%
# Preprocess data

data = preprocess_data(data)

# %%
#  EDA

plot_price(data)
rolling_statistics(data)

# %%
#  Feature Engineering

data = add_moving_averages(data)

# %%
#  Train Model

model_fit = train_arima_model(data, order=(5, 1, 0))
# Out:
# /home/kali/Desktop/Change-point-analysis/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/kali/Desktop/Change-point-analysis/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/kali/Desktop/Change-point-analysis/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
#  Evaluate Model

evaluate_model(model_fit, data, steps=30)
# Out:
# /home/kali/Desktop/Change-point-analysis/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/kali/Desktop/Change-point-analysis/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Mean Absolute Error (MAE): 15.195429021064557
# Root Mean Squared Error (RMSE): 16.318317007139512
